# %% [markdown]
# ## Get OpenSky Data

# %%
from dotenv import load_dotenv

# %%
if not load_dotenv():
    print("Failed to load .env file")

# %%
import requests
from requests.auth import HTTPBasicAuth
from datetime import datetime
import os

keys = [
    "icao24", "callsign", "origin_country", "time_position", "last_contact", "longitude", 
    "latitude", "geo_altitude", "on_ground", "velocity", "true_track", "vertical_rate",
    "sensors","baro_altitude", "squawk", "spi", "position_source", "category"
]

open_sky_user = os.getenv('OPENSKY_USER') or ''
open_sky_password = os.getenv('OPENSKY_PASS') or ''

auth = HTTPBasicAuth(open_sky_user,open_sky_password)

def retrieve_data() :
    url = "https://opensky-network.org/api/states/all"
    optional_params = {
        # 'lamin':48.3,
        # 'lomin':1.5,
        # 'lamax':49.2,
        # 'lomax':3.5
    }
    try:
        response = requests.get(url, auth = auth, params=optional_params)
        response.raise_for_status()
        flights = response.json()
        time = flights["time"]
        values = flights["states"]
        # Get current UTC date and time formated as string
        flight_time = datetime.fromtimestamp(time).isoformat()
        print(flight_time)

        # Recreate dictionary
        info_flights = [{keys[i]: values[j][i] for i in range(len(values[j]))} for j in range(len(values))]
        print("Data collected successfully!\n Number of flights: ", len(info_flights))
        return flight_time, info_flights

    except Exception as e:
        print(e, response.text)

# %%
retrieve_data()
# Out:
# 2024-12-19T15:09:24
# Data collected successfully!
#  Number of flights:  8748
# ('2024-12-19T15:09:24',
#  [{'icao24': 'a89ea5',
#    'callsign': 'N6545H  ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -97.8074,
#    'latitude': 35.6626,
#    'geo_altitude': 731.52,
#    'on_ground': False,
#    'velocity': 39.8,
#    'true_track': 243.1,
#    'vertical_rate': -0.33,
#    'sensors': None,
#    'baro_altitude': 746.76,
#    'squawk': '7314',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4b1816',
#    'callsign': 'SWR935L ',
#    'origin_country': 'Switzerland',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 13.6645,
#    'latitude': 45.306,
#    'geo_altitude': 10988.04,
#    'on_ground': False,
#    'velocity': 218.26,
#    'true_track': 314.62,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 11087.1,
#    'squawk': '2055',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4b1819',
#    'callsign': 'SWR2VK  ',
#    'origin_country': 'Switzerland',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 2.146,
#    'latitude': 41.3301,
#    'geo_altitude': 11887.2,
#    'on_ground': False,
#    'velocity': 186.64,
#    'true_track': 231.27,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 12047.22,
#    'squawk': '3052',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'ac96b8',
#    'callsign': 'AAL386  ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -90.2049,
#    'latitude': 29.9759,
#    'geo_altitude': 480.06,
#    'on_ground': False,
#    'velocity': 107.37,
#    'true_track': 108.43,
#    'vertical_rate': 5.2,
#    'sensors': None,
#    'baro_altitude': 548.64,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '3dd65c',
#    'callsign': 'RDF6    ',
#    'origin_country': 'Germany',
#    'time_position': 1734617255,
#    'last_contact': 1734617260,
#    'longitude': 10.7749,
#    'latitude': 48.7056,
#    'geo_altitude': 541.02,
#    'on_ground': False,
#    'velocity': 15.42,
#    'true_track': 295.71,
#    'vertical_rate': -1.95,
#    'sensors': None,
#    'baro_altitude': 510.54,
#    'squawk': '4402',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a2e5ec',
#    'callsign': 'SKW4115 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -112.5841,
#    'latitude': 34.6906,
#    'geo_altitude': 11582.4,
#    'on_ground': False,
#    'velocity': 200.15,
#    'true_track': 261.72,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 11955.78,
#    'squawk': '3772',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'aa56da',
#    'callsign': 'UAL1093 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -111.9084,
#    'latitude': 36.0406,
#    'geo_altitude': 10972.8,
#    'on_ground': False,
#    'velocity': 215.9,
#    'true_track': 248.33,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 11353.8,
#    'squawk': '1472',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a57b27',
#    'callsign': 'WGN197  ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -88.844,
#    'latitude': 40.8016,
#    'geo_altitude': 11277.6,
#    'on_ground': False,
#    'velocity': 276.71,
#    'true_track': 122.63,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 11231.88,
#    'squawk': '5760',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '7c6b2b',
#    'callsign': 'JST978  ',
#    'origin_country': 'Australia',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 118.9388,
#    'latitude': -31.6116,
#    'geo_altitude': 10363.2,
#    'on_ground': False,
#    'velocity': 206.93,
#    'true_track': 251.29,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 10957.56,
#    'squawk': '1145',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'ade18c',
#    'callsign': 'AAL1333 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -76.7811,
#    'latitude': 36.6714,
#    'geo_altitude': 7940.04,
#    'on_ground': False,
#    'velocity': 236.77,
#    'true_track': 207.57,
#    'vertical_rate': 0.33,
#    'sensors': None,
#    'baro_altitude': 8100.06,
#    'squawk': '7127',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '488284',
#    'callsign': 'SPAWE   ',
#    'origin_country': 'Poland',
#    'time_position': 1734617308,
#    'last_contact': 1734617324,
#    'longitude': 20.9525,
#    'latitude': 52.7017,
#    'geo_altitude': 701.04,
#    'on_ground': False,
#    'velocity': 38.06,
#    'true_track': 170.67,
#    'vertical_rate': -0.98,
#    'sensors': None,
#    'baro_altitude': 601.98,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'ade191',
#    'callsign': 'DAL2071 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -87.335,
#    'latitude': 34.0498,
#    'geo_altitude': 9144,
#    'on_ground': False,
#    'velocity': 202.55,
#    'true_track': 287.74,
#    'vertical_rate': -0.33,
#    'sensors': None,
#    'baro_altitude': 9418.32,
#    'squawk': '4134',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'ab6fdd',
#    'callsign': 'AAL3093 ',
#    'origin_country': 'United States',
#    'time_position': 1734617170,
#    'last_contact': 1734617185,
#    'longitude': -109.4319,
#    'latitude': 28.8053,
#    'geo_altitude': 10972.8,
#    'on_ground': False,
#    'velocity': 232.61,
#    'true_track': 332.75,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 11376.66,
#    'squawk': '3242',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4b1804',
#    'callsign': 'SWR1QW  ',
#    'origin_country': 'Switzerland',
#    'time_position': 1734617359,
#    'last_contact': 1734617359,
#    'longitude': 17.9246,
#    'latitude': 59.6476,
#    'geo_altitude': None,
#    'on_ground': True,
#    'velocity': 0,
#    'true_track': 42.19,
#    'vertical_rate': None,
#    'sensors': None,
#    'baro_altitude': None,
#    'squawk': '1215',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a34e6a',
#    'callsign': 'ENY3360 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -80.0517,
#    'latitude': 25.8255,
#    'geo_altitude': 861.06,
#    'on_ground': False,
#    'velocity': 101.15,
#    'true_track': 226.24,
#    'vertical_rate': -0.33,
#    'sensors': None,
#    'baro_altitude': 929.64,
#    'squawk': '1016',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4b1806',
#    'callsign': 'SWR181V ',
#    'origin_country': 'Switzerland',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 22.0631,
#    'latitude': 38.4414,
#    'geo_altitude': 9532.62,
#    'on_ground': False,
#    'velocity': 212.38,
#    'true_track': 295.7,
#    'vertical_rate': 3.58,
#    'sensors': None,
#    'baro_altitude': 9677.4,
#    'squawk': '2067',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a90ea8',
#    'callsign': 'DAL1227 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -84.3965,
#    'latitude': 30.5431,
#    'geo_altitude': 7620,
#    'on_ground': False,
#    'velocity': 252.59,
#    'true_track': 180.12,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 7848.6,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '80163d',
#    'callsign': 'IGO114  ',
#    'origin_country': 'India',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 85.1081,
#    'latitude': 24.6144,
#    'geo_altitude': 11582.4,
#    'on_ground': False,
#    'velocity': 200.56,
#    'true_track': 300.18,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 12123.42,
#    'squawk': '1322',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'ad4f0b',
#    'callsign': 'DAL2065 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -86.3452,
#    'latitude': 33.0713,
#    'geo_altitude': 5097.78,
#    'on_ground': False,
#    'velocity': 213.74,
#    'true_track': 92.76,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 5273.04,
#    'squawk': '5220',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'aa56d5',
#    'callsign': 'UAL1398 ',
#    'origin_country': 'United States',
#    'time_position': 1734617297,
#    'last_contact': 1734617357,
#    'longitude': -122.3869,
#    'latitude': 37.6225,
#    'geo_altitude': None,
#    'on_ground': True,
#    'velocity': 0,
#    'true_track': 298.12,
#    'vertical_rate': None,
#    'sensors': None,
#    'baro_altitude': None,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '801647',
#    'callsign': 'IGO1807 ',
#    'origin_country': 'India',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 76.8741,
#    'latitude': 28.364,
#    'geo_altitude': 4533.9,
#    'on_ground': False,
#    'velocity': 156.72,
#    'true_track': 284.45,
#    'vertical_rate': 13.33,
#    'sensors': None,
#    'baro_altitude': 4625.34,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '801648',
#    'callsign': 'IGO461  ',
#    'origin_country': 'India',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 76.6865,
#    'latitude': 28.5976,
#    'geo_altitude': 1028.7,
#    'on_ground': False,
#    'velocity': 115.79,
#    'true_track': 14.41,
#    'vertical_rate': -2.6,
#    'sensors': None,
#    'baro_altitude': 1013.46,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4b1800',
#    'callsign': 'SWR2VM  ',
#    'origin_country': 'Switzerland',
#    'time_position': 1734617362,
#    'last_contact': 1734617362,
#    'longitude': 8.5575,
#    'latitude': 47.4518,
#    'geo_altitude': None,
#    'on_ground': True,
#    'velocity': 0,
#    'true_track': 185.62,
#    'vertical_rate': None,
#    'sensors': None,
#    'baro_altitude': None,
#    'squawk': '2000',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a53eef',
#    'callsign': 'UPS7803 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -84.915,
#    'latitude': 35.9862,
#    'geo_altitude': 8542.02,
#    'on_ground': False,
#    'velocity': 252.16,
#    'true_track': 13.81,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 8724.9,
#    'squawk': '2045',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a798c6',
#    'callsign': 'EJA589  ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -79.2551,
#    'latitude': 42.1874,
#    'geo_altitude': 13106.4,
#    'on_ground': False,
#    'velocity': 175.7,
#    'true_track': 249.07,
#    'vertical_rate': 0.33,
#    'sensors': None,
#    'baro_altitude': 12999.72,
#    'squawk': '5754',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'acdfa6',
#    'callsign': 'AAL2758 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -80.8495,
#    'latitude': 34.9759,
#    'geo_altitude': 1127.76,
#    'on_ground': False,
#    'velocity': 97.26,
#    'true_track': 263.93,
#    'vertical_rate': 0.33,
#    'sensors': None,
#    'baro_altitude': 1173.48,
#    'squawk': '3626',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '801650',
#    'callsign': 'AXB174  ',
#    'origin_country': 'India',
#    'time_position': 1734617273,
#    'last_contact': 1734617310,
#    'longitude': 56.5513,
#    'latitude': 25.303,
#    'geo_altitude': 6393.18,
#    'on_ground': False,
#    'velocity': 244.56,
#    'true_track': 109.54,
#    'vertical_rate': 7.48,
#    'sensors': None,
#    'baro_altitude': 6675.12,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a3b88e',
#    'callsign': 'AAL1331 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -102.4466,
#    'latitude': 34.1689,
#    'geo_altitude': 10965.18,
#    'on_ground': False,
#    'velocity': 204.08,
#    'true_track': 285.65,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 11346.18,
#    'squawk': '2331',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'aae316',
#    'callsign': 'AAL3202 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -87.9127,
#    'latitude': 41.9704,
#    'geo_altitude': None,
#    'on_ground': True,
#    'velocity': 6.43,
#    'true_track': 270,
#    'vertical_rate': None,
#    'sensors': None,
#    'baro_altitude': None,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4952cb',
#    'callsign': 'TAP66TS ',
#    'origin_country': 'Portugal',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -1.0163,
#    'latitude': 50.5476,
#    'geo_altitude': 11269.98,
#    'on_ground': False,
#    'velocity': 229.48,
#    'true_track': 235.13,
#    'vertical_rate': 0.33,
#    'sensors': None,
#    'baro_altitude': 11018.52,
#    'squawk': '2103',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4952cc',
#    'callsign': 'TAP781  ',
#    'origin_country': 'Portugal',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 13.839,
#    'latitude': 57.4047,
#    'geo_altitude': 10980.42,
#    'on_ground': False,
#    'velocity': 201.4,
#    'true_track': 222.2,
#    'vertical_rate': 0.33,
#    'sensors': None,
#    'baro_altitude': 10553.7,
#    'squawk': '0767',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '80163f',
#    'callsign': 'AIC2834 ',
#    'origin_country': 'India',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 77.2695,
#    'latitude': 28.0788,
#    'geo_altitude': 3794.76,
#    'on_ground': False,
#    'velocity': 166.1,
#    'true_track': 7.65,
#    'vertical_rate': -3.25,
#    'sensors': None,
#    'baro_altitude': 3870.96,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '880441',
#    'callsign': '',
#    'origin_country': 'Thailand',
#    'time_position': 1734617349,
#    'last_contact': 1734617357,
#    'longitude': 99.7396,
#    'latitude': 10.6378,
#    'geo_altitude': 11277.6,
#    'on_ground': False,
#    'velocity': 235.96,
#    'true_track': 21.76,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 12016.74,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4952cd',
#    'callsign': 'TAP834A ',
#    'origin_country': 'Portugal',
#    'time_position': 1734617362,
#    'last_contact': 1734617363,
#    'longitude': 12.1641,
#    'latitude': 42.0776,
#    'geo_altitude': 1455.42,
#    'on_ground': False,
#    'velocity': 93.23,
#    'true_track': 162.66,
#    'vertical_rate': -3.9,
#    'sensors': None,
#    'baro_altitude': 1516.38,
#    'squawk': '5224',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4952ce',
#    'callsign': 'TAP44LK ',
#    'origin_country': 'Portugal',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -6.103,
#    'latitude': 41.1465,
#    'geo_altitude': 10378.44,
#    'on_ground': False,
#    'velocity': 240.75,
#    'true_track': 42.14,
#    'vertical_rate': -0.33,
#    'sensors': None,
#    'baro_altitude': 10530.84,
#    'squawk': '5206',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a36898',
#    'callsign': 'DAL456  ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -72.4668,
#    'latitude': 42.0915,
#    'geo_altitude': 7299.96,
#    'on_ground': False,
#    'velocity': 197.9,
#    'true_track': 236.02,
#    'vertical_rate': 6.83,
#    'sensors': None,
#    'baro_altitude': 7231.38,
#    'squawk': '3406',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'acdfa3',
#    'callsign': 'ASA150  ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617364,
#    'longitude': -121.1489,
#    'latitude': 38.5216,
#    'geo_altitude': 10058.4,
#    'on_ground': False,
#    'velocity': 237.94,
#    'true_track': 165.6,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 10401.3,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a665c5',
#    'callsign': 'GJS4449 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617364,
#    'longitude': -84.7674,
#    'latitude': 36.8346,
#    'geo_altitude': 10972.8,
#    'on_ground': False,
#    'velocity': 217.67,
#    'true_track': 1.35,
#    'vertical_rate': -0.33,
#    'sensors': None,
#    'baro_altitude': 11155.68,
#    'squawk': '4004',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '880444',
#    'callsign': 'AIQ3395 ',
#    'origin_country': 'Thailand',
#    'time_position': 1734617362,
#    'last_contact': 1734617363,
#    'longitude': 101.6269,
#    'latitude': 14.8697,
#    'geo_altitude': 8100.06,
#    'on_ground': False,
#    'velocity': 217.98,
#    'true_track': 226.63,
#    'vertical_rate': -13,
#    'sensors': None,
#    'baro_altitude': 8663.94,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '7c35c6',
#    'callsign': 'FD628J  ',
#    'origin_country': 'Australia',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 116.2607,
#    'latitude': -30.7212,
#    'geo_altitude': 7315.2,
#    'on_ground': False,
#    'velocity': 203.67,
#    'true_track': 195.23,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 7749.54,
#    'squawk': '7246',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '408107',
#    'callsign': 'VCG1PJ  ',
#    'origin_country': 'United Kingdom',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 1.6606,
#    'latitude': 50.6543,
#    'geo_altitude': 5257.8,
#    'on_ground': False,
#    'velocity': 169.44,
#    'true_track': 290.25,
#    'vertical_rate': -7.15,
#    'sensors': None,
#    'baro_altitude': 5052.06,
#    'squawk': '5741',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'ad19f2',
#    'callsign': 'SKW5794 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -102.0171,
#    'latitude': 33.0815,
#    'geo_altitude': 7292.34,
#    'on_ground': False,
#    'velocity': 189.53,
#    'true_track': 7.8,
#    'vertical_rate': 2.93,
#    'sensors': None,
#    'baro_altitude': 7620,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'ae1fc0',
#    'callsign': 'SAVER25 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -85.198,
#    'latitude': 31.8738,
#    'geo_altitude': 830.58,
#    'on_ground': False,
#    'velocity': 58.03,
#    'true_track': 37.07,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 883.92,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a23565',
#    'callsign': 'TRF50   ',
#    'origin_country': 'United States',
#    'time_position': 1734617248,
#    'last_contact': 1734617361,
#    'longitude': -95.4422,
#    'latitude': 32.7569,
#    'geo_altitude': 1562.1,
#    'on_ground': False,
#    'velocity': 86.99,
#    'true_track': 102.64,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 1630.68,
#    'squawk': '5241',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a5de51',
#    'callsign': 'N4776M  ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -95.0819,
#    'latitude': 32.8535,
#    'geo_altitude': 4030.98,
#    'on_ground': False,
#    'velocity': 124.42,
#    'true_track': 123.36,
#    'vertical_rate': 0.33,
#    'sensors': None,
#    'baro_altitude': 4221.48,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'abacb6',
#    'callsign': 'SCX415  ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617364,
#    'longitude': -91.845,
#    'latitude': 42.3301,
#    'geo_altitude': 11277.6,
#    'on_ground': False,
#    'velocity': 243.92,
#    'true_track': 162.83,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 11140.44,
#    'squawk': '2642',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'ac96be',
#    'callsign': 'AAL2729 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -94.5295,
#    'latitude': 34.2339,
#    'geo_altitude': 9029.7,
#    'on_ground': False,
#    'velocity': 195.74,
#    'true_track': 252.57,
#    'vertical_rate': -5.2,
#    'sensors': None,
#    'baro_altitude': 9349.74,
#    'squawk': '3505',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'ae1fbb',
#    'callsign': 'MESSY12 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -86.0027,
#    'latitude': 30.825,
#    'geo_altitude': 1127.76,
#    'on_ground': False,
#    'velocity': 45.38,
#    'true_track': 273.9,
#    'vertical_rate': -0.33,
#    'sensors': None,
#    'baro_altitude': 1203.96,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a71216',
#    'callsign': 'N555AZ  ',
#    'origin_country': 'United States',
#    'time_position': 1734617195,
#    'last_contact': 1734617195,
#    'longitude': -77.4983,
#    'latitude': 38.6997,
#    'geo_altitude': 30.48,
#    'on_ground': False,
#    'velocity': 32.25,
#    'true_track': 326.06,
#    'vertical_rate': -1.95,
#    'sensors': None,
#    'baro_altitude': 106.68,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a4b228',
#    'callsign': 'UPS2133 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -81.3929,
#    'latitude': 41.3786,
#    'geo_altitude': 12192,
#    'on_ground': False,
#    'velocity': 204.33,
#    'true_track': 242.4,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 12115.8,
#    'squawk': '3424',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '80160f',
#    'callsign': '',
#    'origin_country': 'India',
#    'time_position': None,
#    'last_contact': 1734617338,
#    'longitude': None,
#    'latitude': None,
#    'geo_altitude': None,
#    'on_ground': False,
#    'velocity': 226.29,
#    'true_track': 213.69,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': None,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a65ede',
#    'callsign': 'N5098Q  ',
#    'origin_country': 'United States',
#    'time_position': 1734617356,
#    'last_contact': 1734617356,
#    'longitude': -91.8052,
#    'latitude': 30.2383,
#    'geo_altitude': 2476.5,
#    'on_ground': False,
#    'velocity': 89.46,
#    'true_track': 303.51,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 2613.66,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'aa56b6',
#    'callsign': 'UAL1561 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -85.5359,
#    'latitude': 31.1667,
#    'geo_altitude': 11582.4,
#    'on_ground': False,
#    'velocity': 205.47,
#    'true_track': 303.25,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 11879.58,
#    'squawk': '1134',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4952c9',
#    'callsign': 'TAP76G  ',
#    'origin_country': 'Portugal',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -1.8056,
#    'latitude': 43.4856,
#    'geo_altitude': 10568.94,
#    'on_ground': False,
#    'velocity': 233.77,
#    'true_track': 25.83,
#    'vertical_rate': 2.93,
#    'sensors': None,
#    'baro_altitude': 10591.8,
#    'squawk': '5236',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a46e40',
#    'callsign': 'DAL342  ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617364,
#    'longitude': -83.9655,
#    'latitude': 33.8026,
#    'geo_altitude': 2301.24,
#    'on_ground': False,
#    'velocity': 121.48,
#    'true_track': 191.98,
#    'vertical_rate': -7.15,
#    'sensors': None,
#    'baro_altitude': 2377.44,
#    'squawk': '1434',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a1fb33',
#    'callsign': 'MXY252  ',
#    'origin_country': 'United States',
#    'time_position': 1734617362,
#    'last_contact': 1734617362,
#    'longitude': -79.7629,
#    'latitude': 33.4181,
#    'geo_altitude': 11277.6,
#    'on_ground': False,
#    'velocity': 268.54,
#    'true_track': 43.6,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 11513.82,
#    'squawk': '4516',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'ad5623',
#    'callsign': 'AAL782  ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -101.6001,
#    'latitude': 36.1015,
#    'geo_altitude': 8839.2,
#    'on_ground': False,
#    'velocity': 254.7,
#    'true_track': 136.31,
#    'vertical_rate': -0.33,
#    'sensors': None,
#    'baro_altitude': 9128.76,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'aa56b3',
#    'callsign': 'UAL2189 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -90.8487,
#    'latitude': 37.0278,
#    'geo_altitude': 12192,
#    'on_ground': False,
#    'velocity': 219.02,
#    'true_track': 356.63,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 12344.4,
#    'squawk': '4030',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4952c1',
#    'callsign': 'TAP754A ',
#    'origin_country': 'Portugal',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -5.2813,
#    'latitude': 42.4114,
#    'geo_altitude': 10370.82,
#    'on_ground': False,
#    'velocity': 232.62,
#    'true_track': 25.83,
#    'vertical_rate': 0.33,
#    'sensors': None,
#    'baro_altitude': 10462.26,
#    'squawk': '5441',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '801627',
#    'callsign': 'AIC639  ',
#    'origin_country': 'India',
#    'time_position': 1734617199,
#    'last_contact': 1734617199,
#    'longitude': 80.1497,
#    'latitude': 12.983,
#    'geo_altitude': 83.82,
#    'on_ground': False,
#    'velocity': 71.65,
#    'true_track': 68.96,
#    'vertical_rate': -3.58,
#    'sensors': None,
#    'baro_altitude': -30.48,
#    'squawk': '0335',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '440daf',
#    'callsign': 'EJU7679 ',
#    'origin_country': 'Austria',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 4.0722,
#    'latitude': 46.8093,
#    'geo_altitude': 6408.42,
#    'on_ground': False,
#    'velocity': 212.51,
#    'true_track': 66.91,
#    'vertical_rate': -4.23,
#    'sensors': None,
#    'baro_altitude': 6362.7,
#    'squawk': '1000',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '801625',
#    'callsign': 'AIC667  ',
#    'origin_country': 'India',
#    'time_position': 1734617214,
#    'last_contact': 1734617216,
#    'longitude': 75.7725,
#    'latitude': 11.5066,
#    'geo_altitude': 9563.1,
#    'on_ground': False,
#    'velocity': 236.09,
#    'true_track': 159.2,
#    'vertical_rate': -5.2,
#    'sensors': None,
#    'baro_altitude': 10111.74,
#    'squawk': '0310',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a1c5e0',
#    'callsign': 'ENY3365 ',
#    'origin_country': 'United States',
#    'time_position': 1734617331,
#    'last_contact': 1734617363,
#    'longitude': -97.0265,
#    'latitude': 32.8319,
#    'geo_altitude': 220.98,
#    'on_ground': False,
#    'velocity': 73.57,
#    'true_track': 0.4,
#    'vertical_rate': -4.23,
#    'sensors': None,
#    'baro_altitude': 365.76,
#    'squawk': '4064',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4952c4',
#    'callsign': 'TAP72N  ',
#    'origin_country': 'Portugal',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -4.2304,
#    'latitude': 43.9347,
#    'geo_altitude': 10370.82,
#    'on_ground': False,
#    'velocity': 211.44,
#    'true_track': 23.82,
#    'vertical_rate': -0.33,
#    'sensors': None,
#    'baro_altitude': 10386.06,
#    'squawk': '5255',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4952c5',
#    'callsign': 'TAP553R ',
#    'origin_country': 'Portugal',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -2.1386,
#    'latitude': 42.7241,
#    'geo_altitude': 11277.6,
#    'on_ground': False,
#    'velocity': 193.96,
#    'true_track': 244.05,
#    'vertical_rate': 0.33,
#    'sensors': None,
#    'baro_altitude': 11338.56,
#    'squawk': '2612',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'acdfab',
#    'callsign': 'DAL1613 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -86.7023,
#    'latitude': 35.8204,
#    'geo_altitude': 1310.64,
#    'on_ground': False,
#    'velocity': 112.67,
#    'true_track': 275.5,
#    'vertical_rate': -4.88,
#    'sensors': None,
#    'baro_altitude': 1363.98,
#    'squawk': '2214',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4952c6',
#    'callsign': 'TAP436  ',
#    'origin_country': 'Portugal',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -5.97,
#    'latitude': 41.2575,
#    'geo_altitude': 9753.6,
#    'on_ground': False,
#    'velocity': 227.19,
#    'true_track': 42.61,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 9906,
#    'squawk': '2266',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e48d14',
#    'callsign': 'PROHA   ',
#    'origin_country': 'Brazil',
#    'time_position': 1734617298,
#    'last_contact': 1734617299,
#    'longitude': -40.0237,
#    'latitude': -21.1343,
#    'geo_altitude': 182.88,
#    'on_ground': False,
#    'velocity': 70.96,
#    'true_track': 163.14,
#    'vertical_rate': -3.25,
#    'sensors': None,
#    'baro_altitude': 213.36,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4b180c',
#    'callsign': 'SWR4EC  ',
#    'origin_country': 'Switzerland',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 0.0256,
#    'latitude': 51.4383,
#    'geo_altitude': 1638.3,
#    'on_ground': False,
#    'velocity': 83.97,
#    'true_track': 292.32,
#    'vertical_rate': -2.6,
#    'sensors': None,
#    'baro_altitude': 1607.82,
#    'squawk': '5777',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '39de45',
#    'callsign': 'TVF55VW ',
#    'origin_country': 'France',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 1.3252,
#    'latitude': 47.9631,
#    'geo_altitude': 5768.34,
#    'on_ground': False,
#    'velocity': 175.16,
#    'true_track': 23.18,
#    'vertical_rate': -7.15,
#    'sensors': None,
#    'baro_altitude': 5623.56,
#    'squawk': '1000',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '440db0',
#    'callsign': 'EJU5263 ',
#    'origin_country': 'Austria',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 12.5978,
#    'latitude': 55.0216,
#    'geo_altitude': 3482.34,
#    'on_ground': False,
#    'velocity': 191.48,
#    'true_track': 342,
#    'vertical_rate': -2.6,
#    'sensors': None,
#    'baro_altitude': 3284.22,
#    'squawk': '3756',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '47b22a',
#    'callsign': '',
#    'origin_country': 'Norway',
#    'time_position': None,
#    'last_contact': 1734617361,
#    'longitude': None,
#    'latitude': None,
#    'geo_altitude': None,
#    'on_ground': False,
#    'velocity': 64.26,
#    'true_track': 194.37,
#    'vertical_rate': 10.73,
#    'sensors': None,
#    'baro_altitude': None,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '39de47',
#    'callsign': 'TVF74XH ',
#    'origin_country': 'France',
#    'time_position': 1734617086,
#    'last_contact': 1734617086,
#    'longitude': 2.3553,
#    'latitude': 48.7275,
#    'geo_altitude': None,
#    'on_ground': True,
#    'velocity': 2.57,
#    'true_track': 50.62,
#    'vertical_rate': None,
#    'sensors': None,
#    'baro_altitude': None,
#    'squawk': '1000',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'ac2f5a',
#    'callsign': 'SWA898  ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -83.6138,
#    'latitude': 35.2153,
#    'geo_altitude': 12192,
#    'on_ground': False,
#    'velocity': 217.83,
#    'true_track': 341.69,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 12397.74,
#    'squawk': '1661',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a2ded8',
#    'callsign': 'SWA2573 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617364,
#    'longitude': -119.6626,
#    'latitude': 35.7919,
#    'geo_altitude': 11887.2,
#    'on_ground': False,
#    'velocity': 236.29,
#    'true_track': 117.07,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 12222.48,
#    'squawk': '3245',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '8a02ca',
#    'callsign': 'AWQ326  ',
#    'origin_country': 'Indonesia',
#    'time_position': 1734617289,
#    'last_contact': 1734617297,
#    'longitude': 101.9359,
#    'latitude': 2.1406,
#    'geo_altitude': 2819.4,
#    'on_ground': False,
#    'velocity': 147.14,
#    'true_track': 274.81,
#    'vertical_rate': -4.55,
#    'sensors': None,
#    'baro_altitude': 2994.66,
#    'squawk': '2455',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a46e35',
#    'callsign': 'DAL2406 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -73.1954,
#    'latitude': 40.9959,
#    'geo_altitude': 7147.56,
#    'on_ground': False,
#    'velocity': 242.56,
#    'true_track': 56.68,
#    'vertical_rate': -4.88,
#    'sensors': None,
#    'baro_altitude': 7155.18,
#    'squawk': '2436',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a34215',
#    'callsign': 'EDV4981 ',
#    'origin_country': 'United States',
#    'time_position': 1734617321,
#    'last_contact': 1734617321,
#    'longitude': -73.864,
#    'latitude': 40.7724,
#    'geo_altitude': None,
#    'on_ground': True,
#    'velocity': 3.09,
#    'true_track': 185.62,
#    'vertical_rate': None,
#    'sensors': None,
#    'baro_altitude': None,
#    'squawk': '2132',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '440db9',
#    'callsign': 'OEXDC   ',
#    'origin_country': 'Austria',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 13.0801,
#    'latitude': 47.7787,
#    'geo_altitude': 914.4,
#    'on_ground': False,
#    'velocity': 33.57,
#    'true_track': 15.1,
#    'vertical_rate': -0.65,
#    'sensors': None,
#    'baro_altitude': 922.02,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a2355d',
#    'callsign': 'SKW3996 ',
#    'origin_country': 'United States',
#    'time_position': 1734617362,
#    'last_contact': 1734617363,
#    'longitude': -93.7705,
#    'latitude': 45.1503,
#    'geo_altitude': 1531.62,
#    'on_ground': False,
#    'velocity': 76.25,
#    'true_track': 217.87,
#    'vertical_rate': -2.28,
#    'sensors': None,
#    'baro_altitude': 1463.04,
#    'squawk': '2102',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '39de42',
#    'callsign': 'TVF4605 ',
#    'origin_country': 'France',
#    'time_position': 1734617285,
#    'last_contact': 1734617308,
#    'longitude': 2.4395,
#    'latitude': 48.7343,
#    'geo_altitude': 304.8,
#    'on_ground': False,
#    'velocity': 64.89,
#    'true_track': 255.3,
#    'vertical_rate': -2.6,
#    'sensors': None,
#    'baro_altitude': 327.66,
#    'squawk': '1000',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a72532',
#    'callsign': 'N56GL   ',
#    'origin_country': 'United States',
#    'time_position': None,
#    'last_contact': 1734617181,
#    'longitude': None,
#    'latitude': None,
#    'geo_altitude': None,
#    'on_ground': False,
#    'velocity': 68.32,
#    'true_track': 307.04,
#    'vertical_rate': -0.33,
#    'sensors': None,
#    'baro_altitude': None,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '39de41',
#    'callsign': 'TVF82NN ',
#    'origin_country': 'France',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 7.965,
#    'latitude': 47.8189,
#    'geo_altitude': 11277.6,
#    'on_ground': False,
#    'velocity': 255.03,
#    'true_track': 104.01,
#    'vertical_rate': 0.33,
#    'sensors': None,
#    'baro_altitude': 11163.3,
#    'squawk': '5616',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4952ad',
#    'callsign': 'TAP093  ',
#    'origin_country': 'Portugal',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -8.8539,
#    'latitude': 41.2973,
#    'geo_altitude': 1508.76,
#    'on_ground': False,
#    'velocity': 139.66,
#    'true_track': 244,
#    'vertical_rate': 8.13,
#    'sensors': None,
#    'baro_altitude': 1676.4,
#    'squawk': '3347',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4b180b',
#    'callsign': 'SWR     ',
#    'origin_country': 'Switzerland',
#    'time_position': 1734617361,
#    'last_contact': 1734617362,
#    'longitude': 8.5599,
#    'latitude': 47.4515,
#    'geo_altitude': 502.92,
#    'on_ground': True,
#    'velocity': 0,
#    'true_track': 185.62,
#    'vertical_rate': None,
#    'sensors': None,
#    'baro_altitude': None,
#    'squawk': '2000',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4952af',
#    'callsign': 'TAP073  ',
#    'origin_country': 'Portugal',
#    'time_position': 1734617326,
#    'last_contact': 1734617338,
#    'longitude': -10.4169,
#    'latitude': 35.5795,
#    'geo_altitude': 10058.4,
#    'on_ground': False,
#    'velocity': 219.77,
#    'true_track': 216.82,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 10469.88,
#    'squawk': '3373',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'ac2f83',
#    'callsign': 'SWA280  ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -112.2577,
#    'latitude': 32.9617,
#    'geo_altitude': 10668,
#    'on_ground': False,
#    'velocity': 246.88,
#    'true_track': 101.05,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 11079.48,
#    'squawk': '1026',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '3c6668',
#    'callsign': 'DLH1AC  ',
#    'origin_country': 'Germany',
#    'time_position': 1734617362,
#    'last_contact': 1734617363,
#    'longitude': 15.9862,
#    'latitude': 58.2692,
#    'geo_altitude': 9509.76,
#    'on_ground': False,
#    'velocity': 205.37,
#    'true_track': 208.75,
#    'vertical_rate': 5.53,
#    'sensors': None,
#    'baro_altitude': 9075.42,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '8a02d6',
#    'callsign': 'GIA193  ',
#    'origin_country': 'Indonesia',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 102.2671,
#    'latitude': 0.7517,
#    'geo_altitude': 11277.6,
#    'on_ground': False,
#    'velocity': 226.12,
#    'true_track': 140.26,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 12039.6,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '505f03',
#    'callsign': 'OMS011  ',
#    'origin_country': 'Slovakia',
#    'time_position': 1734617335,
#    'last_contact': 1734617343,
#    'longitude': 17.4167,
#    'latitude': 48.6706,
#    'geo_altitude': 678.18,
#    'on_ground': False,
#    'velocity': 45.3,
#    'true_track': 285.14,
#    'vertical_rate': -2.28,
#    'sensors': None,
#    'baro_altitude': 624.84,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '3c6667',
#    'callsign': 'DLH9KV  ',
#    'origin_country': 'Germany',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 8.6474,
#    'latitude': 50.0545,
#    'geo_altitude': 502.92,
#    'on_ground': False,
#    'velocity': 66.9,
#    'true_track': 249.75,
#    'vertical_rate': -3.9,
#    'sensors': None,
#    'baro_altitude': 419.1,
#    'squawk': '5660',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '3c6666',
#    'callsign': 'DLH850  ',
#    'origin_country': 'Germany',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 14.3644,
#    'latitude': 56.2048,
#    'geo_altitude': 10660.38,
#    'on_ground': False,
#    'velocity': 255.96,
#    'true_track': 40.03,
#    'vertical_rate': 0.33,
#    'sensors': None,
#    'baro_altitude': 10271.76,
#    'squawk': '3735',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a2228b',
#    'callsign': 'ASA836  ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -94.3286,
#    'latitude': 34.5921,
#    'geo_altitude': 10363.2,
#    'on_ground': False,
#    'velocity': 199.79,
#    'true_track': 298.28,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 10668,
#    'squawk': '2140',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '511188',
#    'callsign': 'MBU8KZ  ',
#    'origin_country': 'Estonia',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -3.0952,
#    'latitude': 40.3675,
#    'geo_altitude': 10965.18,
#    'on_ground': False,
#    'velocity': 269.99,
#    'true_track': 39.67,
#    'vertical_rate': 0.33,
#    'sensors': None,
#    'baro_altitude': 11163.3,
#    'squawk': '5267',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '8a02d3',
#    'callsign': 'GIA328  ',
#    'origin_country': 'Indonesia',
#    'time_position': 1734617287,
#    'last_contact': 1734617287,
#    'longitude': 112.7006,
#    'latitude': -7.5149,
#    'geo_altitude': 3794.76,
#    'on_ground': False,
#    'velocity': 166.86,
#    'true_track': 114.98,
#    'vertical_rate': -7.8,
#    'sensors': None,
#    'baro_altitude': 4038.6,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'abacd2',
#    'callsign': 'UAL1610 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -74.8019,
#    'latitude': 39.537,
#    'geo_altitude': 9464.04,
#    'on_ground': False,
#    'velocity': 220.09,
#    'true_track': 225.47,
#    'vertical_rate': 5.53,
#    'sensors': None,
#    'baro_altitude': 9532.62,
#    'squawk': '1624',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '0aa006',
#    'callsign': '',
#    'origin_country': 'Barbados',
#    'time_position': None,
#    'last_contact': 1734617257,
#    'longitude': None,
#    'latitude': None,
#    'geo_altitude': None,
#    'on_ground': False,
#    'velocity': 90.06,
#    'true_track': 358.36,
#    'vertical_rate': 8.13,
#    'sensors': None,
#    'baro_altitude': None,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'aaef89',
#    'callsign': 'AAL2589 ',
#    'origin_country': 'United States',
#    'time_position': 1734617331,
#    'last_contact': 1734617333,
#    'longitude': -81.3067,
#    'latitude': 26.1273,
#    'geo_altitude': 6827.52,
#    'on_ground': False,
#    'velocity': 210.69,
#    'true_track': 136.48,
#    'vertical_rate': -9.1,
#    'sensors': None,
#    'baro_altitude': 7185.66,
#    'squawk': '7662',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '408166',
#    'callsign': 'LJC9    ',
#    'origin_country': 'United Kingdom',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 5.4635,
#    'latitude': 50.4964,
#    'geo_altitude': 13106.4,
#    'on_ground': False,
#    'velocity': 198.61,
#    'true_track': 303.48,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 12893.04,
#    'squawk': '2753',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4acb02',
#    'callsign': 'NSZ43E  ',
#    'origin_country': 'Sweden',
#    'time_position': 1734617362,
#    'last_contact': 1734617362,
#    'longitude': 17.9215,
#    'latitude': 59.6475,
#    'geo_altitude': None,
#    'on_ground': True,
#    'velocity': 5.4,
#    'true_track': 286.88,
#    'vertical_rate': None,
#    'sensors': None,
#    'baro_altitude': None,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'ad4f72',
#    'callsign': 'JBU2321 ',
#    'origin_country': 'United States',
#    'time_position': 1734617303,
#    'last_contact': 1734617329,
#    'longitude': -79.9757,
#    'latitude': 26.9178,
#    'geo_altitude': 1165.86,
#    'on_ground': False,
#    'velocity': 137.95,
#    'true_track': 169.91,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 1242.06,
#    'squawk': '0630',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '3c664f',
#    'callsign': 'DLH68M  ',
#    'origin_country': 'Germany',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 5.4534,
#    'latitude': 42.9292,
#    'geo_altitude': 10370.82,
#    'on_ground': False,
#    'velocity': 269.09,
#    'true_track': 42.44,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 10447.02,
#    'squawk': '5553',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4acb04',
#    'callsign': 'NSZ4457 ',
#    'origin_country': 'Sweden',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 15.2498,
#    'latitude': 59.2305,
#    'geo_altitude': 10721.34,
#    'on_ground': False,
#    'velocity': 201.37,
#    'true_track': 233.83,
#    'vertical_rate': 6.5,
#    'sensors': None,
#    'baro_altitude': 10233.66,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'adffbc',
#    'callsign': 'JUMP97  ',
#    'origin_country': 'United States',
#    'time_position': 1734617361,
#    'last_contact': 1734617361,
#    'longitude': -100.0651,
#    'latitude': 29.4498,
#    'geo_altitude': 3406.14,
#    'on_ground': False,
#    'velocity': 178.15,
#    'true_track': 274.97,
#    'vertical_rate': -7.48,
#    'sensors': None,
#    'baro_altitude': 3596.64,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '51116c',
#    'callsign': 'ESABB   ',
#    'origin_country': 'Estonia',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 15.8149,
#    'latitude': 49.2549,
#    'geo_altitude': 1082.04,
#    'on_ground': False,
#    'velocity': 71.82,
#    'true_track': 58.47,
#    'vertical_rate': 0.65,
#    'sensors': None,
#    'baro_altitude': 1005.84,
#    'squawk': '7537',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4bc8c6',
#    'callsign': 'PGT19HG ',
#    'origin_country': 'Turkey',
#    'time_position': 1734617363,
#    'last_contact': 1734617364,
#    'longitude': 18.0539,
#    'latitude': 47.0302,
#    'geo_altitude': 10965.18,
#    'on_ground': False,
#    'velocity': 210.17,
#    'true_track': 298.51,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 11049,
#    'squawk': '2664',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '40814a',
#    'callsign': 'AUR686D ',
#    'origin_country': 'United Kingdom',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -4.3874,
#    'latitude': 51.3452,
#    'geo_altitude': 4267.2,
#    'on_ground': False,
#    'velocity': 114.48,
#    'true_track': 330.67,
#    'vertical_rate': 0.98,
#    'sensors': None,
#    'baro_altitude': 4191,
#    'squawk': '3776',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'e80259',
#    'callsign': 'LPE2384 ',
#    'origin_country': 'Chile',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -76.1737,
#    'latitude': -8.2069,
#    'geo_altitude': 11277.6,
#    'on_ground': False,
#    'velocity': 228.28,
#    'true_track': 9.99,
#    'vertical_rate': 0.33,
#    'sensors': None,
#    'baro_altitude': 12039.6,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4bc8c3',
#    'callsign': 'PGT3XU  ',
#    'origin_country': 'Turkey',
#    'time_position': 1734617362,
#    'last_contact': 1734617363,
#    'longitude': 29.5902,
#    'latitude': 41.0017,
#    'geo_altitude': 1409.7,
#    'on_ground': False,
#    'velocity': 95.95,
#    'true_track': 244.26,
#    'vertical_rate': -4.23,
#    'sensors': None,
#    'baro_altitude': 1478.28,
#    'squawk': '0416',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '3c6664',
#    'callsign': 'DLH1VV  ',
#    'origin_country': 'Germany',
#    'time_position': 1734617347,
#    'last_contact': 1734617351,
#    'longitude': 11.8097,
#    'latitude': 48.3452,
#    'geo_altitude': 563.88,
#    'on_ground': False,
#    'velocity': 65.79,
#    'true_track': 263.26,
#    'vertical_rate': -3.25,
#    'sensors': None,
#    'baro_altitude': 518.16,
#    'squawk': '1000',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '3c6663',
#    'callsign': 'DLH09H  ',
#    'origin_country': 'Germany',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 4.2474,
#    'latitude': 49.1024,
#    'geo_altitude': 10561.32,
#    'on_ground': False,
#    'velocity': 266.21,
#    'true_track': 66.9,
#    'vertical_rate': -4.88,
#    'sensors': None,
#    'baro_altitude': 10309.86,
#    'squawk': '1000',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4bc8c1',
# ...
#   {'icao24': '8015e7',
#    'callsign': 'IGO51VK ',
#    'origin_country': 'India',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 88.3233,
#    'latitude': 22.2956,
#    'geo_altitude': 6408.42,
#    'on_ground': False,
#    'velocity': 194.88,
#    'true_track': 93.78,
#    'vertical_rate': -4.55,
#    'sensors': None,
#    'baro_altitude': 6705.6,
#    'squawk': '2715',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a9536f',
#    'callsign': 'BMJ70   ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617364,
#    'longitude': -93.1493,
#    'latitude': 45.467,
#    'geo_altitude': 2415.54,
#    'on_ground': False,
#    'velocity': 119.02,
#    'true_track': 356.78,
#    'vertical_rate': -0.65,
#    'sensors': None,
#    'baro_altitude': 2331.72,
#    'squawk': '4265',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a2bb89',
#    'callsign': 'UAL507  ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -85.2765,
#    'latitude': 42.4532,
#    'geo_altitude': 9075.42,
#    'on_ground': False,
#    'velocity': 203.28,
#    'true_track': 271.6,
#    'vertical_rate': 7.48,
#    'sensors': None,
#    'baro_altitude': 9014.46,
#    'squawk': '5001',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a6b833',
#    'callsign': 'DAL777  ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -85.1669,
#    'latitude': 33.8092,
#    'geo_altitude': 5082.54,
#    'on_ground': False,
#    'velocity': 185.95,
#    'true_track': 287.88,
#    'vertical_rate': 9.75,
#    'sensors': None,
#    'baro_altitude': 5257.8,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '8015e6',
#    'callsign': 'IGO49P  ',
#    'origin_country': 'India',
#    'time_position': 1734617081,
#    'last_contact': 1734617082,
#    'longitude': 78.093,
#    'latitude': 15.3272,
#    'geo_altitude': 9144,
#    'on_ground': False,
#    'velocity': 232.07,
#    'true_track': 9.44,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 9677.4,
#    'squawk': '1000',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '3c64f3',
#    'callsign': 'DLH433  ',
#    'origin_country': 'Germany',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 8.6431,
#    'latitude': 50.2506,
#    'geo_altitude': 2796.54,
#    'on_ground': False,
#    'velocity': 154.1,
#    'true_track': 80,
#    'vertical_rate': -4.55,
#    'sensors': None,
#    'baro_altitude': 2689.86,
#    'squawk': '5220',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '39d1aa',
#    'callsign': 'OYO5    ',
#    'origin_country': 'France',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 2.6883,
#    'latitude': 48.9779,
#    'geo_altitude': 944.88,
#    'on_ground': False,
#    'velocity': 121.72,
#    'true_track': 265.88,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 922.02,
#    'squawk': '1000',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'ab525f',
#    'callsign': 'AAL3099 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617364,
#    'longitude': -88.1989,
#    'latitude': 42.8297,
#    'geo_altitude': 10980.42,
#    'on_ground': False,
#    'velocity': 211.35,
#    'true_track': 314.9,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 10835.64,
#    'squawk': '2002',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a27299',
#    'callsign': 'NIT257  ',
#    'origin_country': 'United States',
#    'time_position': 1734617082,
#    'last_contact': 1734617082,
#    'longitude': -82.7937,
#    'latitude': 32.2796,
#    'geo_altitude': 1104.9,
#    'on_ground': False,
#    'velocity': 47.4,
#    'true_track': 117.12,
#    'vertical_rate': -4.23,
#    'sensors': None,
#    'baro_altitude': 1158.24,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '3c4acd',
#    'callsign': 'DLH754  ',
#    'origin_country': 'Germany',
#    'time_position': 1734617363,
#    'last_contact': 1734617364,
#    'longitude': 20.7297,
#    'latitude': 46.9679,
#    'geo_altitude': 10668,
#    'on_ground': False,
#    'velocity': 263.1,
#    'true_track': 123.6,
#    'vertical_rate': -0.33,
#    'sensors': None,
#    'baro_altitude': 10736.58,
#    'squawk': '6433',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a64e2a',
#    'callsign': 'SKW4867 ',
#    'origin_country': 'United States',
#    'time_position': 1734617325,
#    'last_contact': 1734617325,
#    'longitude': -106.6158,
#    'latitude': 35.0363,
#    'geo_altitude': None,
#    'on_ground': True,
#    'velocity': 8.75,
#    'true_track': 225,
#    'vertical_rate': None,
#    'sensors': None,
#    'baro_altitude': None,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'c82396',
#    'callsign': 'AWK64   ',
#    'origin_country': 'New Zealand',
#    'time_position': 1734617359,
#    'last_contact': 1734617361,
#    'longitude': 175.6876,
#    'latitude': -40.3336,
#    'geo_altitude': 1181.1,
#    'on_ground': False,
#    'velocity': 113.12,
#    'true_track': 141.46,
#    'vertical_rate': 15.28,
#    'sensors': None,
#    'baro_altitude': 1074.42,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4080c1',
#    'callsign': 'RUK9YQ  ',
#    'origin_country': 'United Kingdom',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -7.708,
#    'latitude': 37.8097,
#    'geo_altitude': 11582.4,
#    'on_ground': False,
#    'velocity': 238.1,
#    'true_track': 15.03,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 11925.3,
#    'squawk': '6404',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4080c2',
#    'callsign': 'RUK48CX ',
#    'origin_country': 'United Kingdom',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 6.8254,
#    'latitude': 51.127,
#    'geo_altitude': 11285.22,
#    'on_ground': False,
#    'velocity': 251.37,
#    'true_track': 120.5,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 10988.04,
#    'squawk': '5206',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'ab5278',
#    'callsign': 'N829BW  ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -70.8927,
#    'latitude': 41.8943,
#    'geo_altitude': 1005.84,
#    'on_ground': False,
#    'velocity': 32.45,
#    'true_track': 2.73,
#    'vertical_rate': -5.2,
#    'sensors': None,
#    'baro_altitude': 998.22,
#    'squawk': '1200',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'ae62b4',
#    'callsign': 'HAWK211 ',
#    'origin_country': 'United States',
#    'time_position': 1734617362,
#    'last_contact': 1734617363,
#    'longitude': -98.0769,
#    'latitude': 27.1765,
#    'geo_altitude': 3558.54,
#    'on_ground': False,
#    'velocity': 158.54,
#    'true_track': 207.65,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 3771.9,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a51b1a',
#    'callsign': 'UAL2051 ',
#    'origin_country': 'United States',
#    'time_position': 1734617360,
#    'last_contact': 1734617360,
#    'longitude': -106.1725,
#    'latitude': 31.8595,
#    'geo_altitude': 10355.58,
#    'on_ground': False,
#    'velocity': 226.63,
#    'true_track': 292.84,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 10797.54,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a52e4d',
#    'callsign': 'N433AK  ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617364,
#    'longitude': -118.4772,
#    'latitude': 34.1032,
#    'geo_altitude': 640.08,
#    'on_ground': False,
#    'velocity': 55.41,
#    'true_track': 344.93,
#    'vertical_rate': 1.63,
#    'sensors': None,
#    'baro_altitude': 685.8,
#    'squawk': '1200',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'ade201',
#    'callsign': 'BVN8200 ',
#    'origin_country': 'United States',
#    'time_position': 1734617362,
#    'last_contact': 1734617363,
#    'longitude': -100.7428,
#    'latitude': 33.0157,
#    'geo_altitude': 2644.14,
#    'on_ground': False,
#    'velocity': 88.61,
#    'true_track': 123.87,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 2766.06,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'abb57a',
#    'callsign': 'ASH6090 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': -79.8438,
#    'latitude': 40.3466,
#    'geo_altitude': 2133.6,
#    'on_ground': False,
#    'velocity': 129.76,
#    'true_track': 322.09,
#    'vertical_rate': -7.8,
#    'sensors': None,
#    'baro_altitude': 2133.6,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '782188',
#    'callsign': 'CSN8020 ',
#    'origin_country': 'China',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 101.3356,
#    'latitude': 14.0137,
#    'geo_altitude': 5120.64,
#    'on_ground': False,
#    'velocity': 189.28,
#    'true_track': 67.13,
#    'vertical_rate': 12.68,
#    'sensors': None,
#    'baro_altitude': 5379.72,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '3c4ada',
#    'callsign': 'DLH470  ',
#    'origin_country': 'Germany',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 2.6552,
#    'latitude': 53.1966,
#    'geo_altitude': 10363.2,
#    'on_ground': False,
#    'velocity': 239.67,
#    'true_track': 293.26,
#    'vertical_rate': -0.33,
#    'sensors': None,
#    'baro_altitude': 9951.72,
#    'squawk': '0137',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a605bd',
#    'callsign': 'N48753  ',
#    'origin_country': 'United States',
#    'time_position': 1734617360,
#    'last_contact': 1734617362,
#    'longitude': -76.2689,
#    'latitude': 39.5543,
#    'geo_altitude': 426.72,
#    'on_ground': False,
#    'velocity': 45.28,
#    'true_track': 68.68,
#    'vertical_rate': -3.25,
#    'sensors': None,
#    'baro_altitude': 449.58,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '88530f',
#    'callsign': 'THA636  ',
#    'origin_country': 'Thailand',
#    'time_position': 1734617362,
#    'last_contact': 1734617363,
#    'longitude': 120.4444,
#    'latitude': 24.1959,
#    'geo_altitude': 5532.12,
#    'on_ground': False,
#    'velocity': 176.04,
#    'true_track': 17.69,
#    'vertical_rate': -7.48,
#    'sensors': None,
#    'baro_altitude': 5775.96,
#    'squawk': '6137',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '8015f0',
#    'callsign': 'AXB2834 ',
#    'origin_country': 'India',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 78.096,
#    'latitude': 14.1274,
#    'geo_altitude': 9448.8,
#    'on_ground': False,
#    'velocity': 239.94,
#    'true_track': 193.77,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 9989.82,
#    'squawk': '1000',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4080ad',
#    'callsign': 'EZY96KL ',
#    'origin_country': 'United Kingdom',
#    'time_position': 1734617364,
#    'last_contact': 1734617364,
#    'longitude': -0.7877,
#    'latitude': 50.7249,
#    'geo_altitude': 6408.42,
#    'on_ground': False,
#    'velocity': 153.35,
#    'true_track': 13.38,
#    'vertical_rate': -9.43,
#    'sensors': None,
#    'baro_altitude': 6195.06,
#    'squawk': '2347',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '873334',
#    'callsign': 'ANA204  ',
#    'origin_country': 'Japan',
#    'time_position': 1734617356,
#    'last_contact': 1734617359,
#    'longitude': 41.8907,
#    'latitude': 41.2913,
#    'geo_altitude': 10660.38,
#    'on_ground': False,
#    'velocity': 261.09,
#    'true_track': 80.13,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 10744.2,
#    'squawk': '6422',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'ac22ea',
#    'callsign': 'N881Q   ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617364,
#    'longitude': -88.9715,
#    'latitude': 34.8699,
#    'geo_altitude': 8602.98,
#    'on_ground': False,
#    'velocity': 234.22,
#    'true_track': 104.89,
#    'vertical_rate': 11.7,
#    'sensors': None,
#    'baro_altitude': 8846.82,
#    'squawk': '1570',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '39348e',
#    'callsign': 'TVF96UH ',
#    'origin_country': 'France',
#    'time_position': 1734617362,
#    'last_contact': 1734617363,
#    'longitude': 3.376,
#    'latitude': 48.1219,
#    'geo_altitude': 4853.94,
#    'on_ground': False,
#    'velocity': 173.85,
#    'true_track': 305.24,
#    'vertical_rate': -8.78,
#    'sensors': None,
#    'baro_altitude': 4747.26,
#    'squawk': '1000',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4a08ea',
#    'callsign': 'ROT383X ',
#    'origin_country': 'Romania',
#    'time_position': 1734617302,
#    'last_contact': 1734617303,
#    'longitude': 2.58,
#    'latitude': 49.0277,
#    'geo_altitude': 236.22,
#    'on_ground': False,
#    'velocity': 67.08,
#    'true_track': 265.6,
#    'vertical_rate': -3.9,
#    'sensors': None,
#    'baro_altitude': 243.84,
#    'squawk': '1000',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '782198',
#    'callsign': 'CES9864 ',
#    'origin_country': 'China',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 123.9548,
#    'latitude': 39.4101,
#    'geo_altitude': 10698.48,
#    'on_ground': False,
#    'velocity': 203.2,
#    'true_track': 184.06,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 10568.94,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4a08ec',
#    'callsign': 'ROT382A ',
#    'origin_country': 'Romania',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 24.503,
#    'latitude': 44.9803,
#    'geo_altitude': 7840.98,
#    'on_ground': False,
#    'velocity': 244.6,
#    'true_track': 115.54,
#    'vertical_rate': -13.98,
#    'sensors': None,
#    'baro_altitude': 7985.76,
#    'squawk': '1000',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a1a286',
#    'callsign': 'SKW5549 ',
#    'origin_country': 'United States',
#    'time_position': 1734617363,
#    'last_contact': 1734617364,
#    'longitude': -122.4878,
#    'latitude': 37.7243,
#    'geo_altitude': 3284.22,
#    'on_ground': False,
#    'velocity': 151.89,
#    'true_track': 139.95,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 3436.62,
#    'squawk': '4262',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': 'a63b16',
#    'callsign': 'N500MU  ',
#    'origin_country': 'United States',
#    'time_position': 1734617119,
#    'last_contact': 1734617121,
#    'longitude': -77.2961,
#    'latitude': 39.5425,
#    'geo_altitude': 167.64,
#    'on_ground': False,
#    'velocity': 61.17,
#    'true_track': 71.87,
#    'vertical_rate': -0.98,
#    'sensors': None,
#    'baro_altitude': 228.6,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '782191',
#    'callsign': 'HLF8877 ',
#    'origin_country': 'China',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 53.8106,
#    'latitude': 59.4888,
#    'geo_altitude': 9753.6,
#    'on_ground': False,
#    'velocity': 236.99,
#    'true_track': 273.11,
#    'vertical_rate': 0,
#    'sensors': None,
#    'baro_altitude': 9128.76,
#    'squawk': '3135',
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '885315',
#    'callsign': 'THA557  ',
#    'origin_country': 'Thailand',
#    'time_position': 1734617363,
#    'last_contact': 1734617363,
#    'longitude': 102.3815,
#    'latitude': 12.7891,
#    'geo_altitude': 10972.8,
#    'on_ground': False,
#    'velocity': 215.97,
#    'true_track': 264.67,
#    'vertical_rate': -0.98,
#    'sensors': None,
#    'baro_altitude': 11727.18,
#    'squawk': None,
#    'spi': False,
#    'position_source': 0},
#   {'icao24': '4009c5',
#    'callsign': 'SHT8T   ',
#    'origin_country': 'United Kingdom',
#    'time_position': 1734617317,
#    'last_contact': 1734617317,
#    'longitude': -3.368,
#    'latitude': 55.9489,
#    'geo_altitude': None,
#    'on_ground': True,
#    'velocity': 3.34,
#    'true_track': 149.06,
#    'vertical_rate': None,
#    'sensors': None,
#    'baro_altitude': None,
#    'squawk': '6032',
#    'spi': False,
#    'position_source': 0},
#   ...])

# %% [markdown]
# ## Send to Event Hub

# %%
# %pip install azure-eventhub
# Out:
# Requirement already satisfied: azure-eventhub in c:\users\williamrussell\appdata\local\programs\python\python312\lib\site-packages (5.13.0)
# Requirement already satisfied: azure-core>=1.27.0 in c:\users\williamrussell\appdata\local\programs\python\python312\lib\site-packages (from azure-eventhub) (1.32.0)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\williamrussell\appdata\local\programs\python\python312\lib\site-packages (from azure-eventhub) (4.12.2)
# Requirement already satisfied: requests>=2.21.0 in c:\users\williamrussell\appdata\local\programs\python\python312\lib\site-packages (from azure-core>=1.27.0->azure-eventhub) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\williamrussell\appdata\roaming\python\python312\site-packages (from azure-core>=1.27.0->azure-eventhub) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\williamrussell\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.21.0->azure-core>=1.27.0->azure-eventhub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\williamrussell\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.21.0->azure-core>=1.27.0->azure-eventhub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\williamrussell\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.21.0->azure-core>=1.27.0->azure-eventhub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\williamrussell\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.21.0->azure-core>=1.27.0->azure-eventhub) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
from azure.eventhub import EventData
from azure.eventhub.aio import EventHubProducerClient

import time
import asyncio
import json
import os

# %%
EVENT_HUB_CONNECTION_STR = os.getenv('EVENT_HUB_CONNECTION_STR') or ''
EVENT_HUB_NAME = os.getenv("EVENT_HUB_NAME") or '' #name of hub NOT THE NAMESPACE

# %%
async def send_data():
    # create a producer to send message to the event hub
    # specify a connection string to your event hubs namespace and the event hub name
    producer = EventHubProducerClient.from_connection_string(
        conn_str=EVENT_HUB_CONNECTION_STR,
        eventhub_name=EVENT_HUB_NAME
    )
    
    async with producer:
        data = retrieve_data()
        if data is None:
            print("No data to send")
            return
    
        time_request = data[0]
        flights = data[1]
        if len(flights) <= 0:
            print("No flights data")
            return
        try:
            await send_batches(producer, time_request, flights)
        except:
            print("Error while sending data")

async def send_batches(producer:EventHubProducerClient, time_request:str, flights:list):
    #create a batch of events
    event_data_batch = await producer.create_batch()
    
    for element in flights:
        # Add events to the batch.
        element["time"] = time_request
        event_data = EventData(json.dumps(element).replace('None', ''))
        try:
            event_data_batch.add(event_data)
        except ValueError: # if the batch is full, send it, then create a new batch, and add the event to the new batch
            #send the batch of events to the event hub
            await producer.send_batch(event_data_batch)
            print(f"Batch sent: {time_request}, size: {len(event_data_batch)}")
            
            event_data_batch = await producer.create_batch()
            event_data_batch.add(event_data) # this event would be lost (not included in the previous batch) 
            
    #send the batch of events to the event hub
    await producer.send_batch(event_data_batch)
    print(f"Batch sent: {time_request}, size: {len(event_data_batch)}")

# %%
async def run_async(duration:float, frequency:float):
    end_time = time.time() + (60 * duration) # in seconds
    while time.time() < end_time:
        start_time = time.time()
        await send_data()
        waiting_time = 60/frequency
        processing_time = time.time() - start_time
        await asyncio.sleep(waiting_time - processing_time)

# %%
# import sys
# run_async(float(sys.argv[1]), float(sys.argv[2]))
await run_async(duration=2, frequency=1) # 2 minutes, 1 call per minute
# asyncio.run(run_async(duration=2, frequency=1))
# Out:
# 2024-12-19T16:36:14
# Data collected successfully!
#  Number of flights:  10147
# Batch sent: 2024-12-19T16:36:14, size: 613
# Batch sent: 2024-12-19T16:36:14, size: 613
# Batch sent: 2024-12-19T16:36:14, size: 611
# Batch sent: 2024-12-19T16:36:14, size: 611
# Batch sent: 2024-12-19T16:36:14, size: 612
# Batch sent: 2024-12-19T16:36:14, size: 611
# Batch sent: 2024-12-19T16:36:14, size: 613
# Batch sent: 2024-12-19T16:36:14, size: 611
# Batch sent: 2024-12-19T16:36:14, size: 612
# Batch sent: 2024-12-19T16:36:14, size: 612
# Batch sent: 2024-12-19T16:36:14, size: 612
# Batch sent: 2024-12-19T16:36:14, size: 612
# Batch sent: 2024-12-19T16:36:14, size: 612
# Batch sent: 2024-12-19T16:36:14, size: 612
# Batch sent: 2024-12-19T16:36:14, size: 613
# Batch sent: 2024-12-19T16:36:14, size: 613
# Batch sent: 2024-12-19T16:36:14, size: 354
# 2024-12-19T16:37:13
# Data collected successfully!
#  Number of flights:  10168
# Batch sent: 2024-12-19T16:37:13, size: 613
# Batch sent: 2024-12-19T16:37:13, size: 612
# Batch sent: 2024-12-19T16:37:13, size: 611
# Batch sent: 2024-12-19T16:37:13, size: 611
# Batch sent: 2024-12-19T16:37:13, size: 613
# Batch sent: 2024-12-19T16:37:13, size: 611
# Batch sent: 2024-12-19T16:37:13, size: 613
# Batch sent: 2024-12-19T16:37:13, size: 611
# Batch sent: 2024-12-19T16:37:13, size: 612
# Batch sent: 2024-12-19T16:37:13, size: 613
# Batch sent: 2024-12-19T16:37:13, size: 612
# Batch sent: 2024-12-19T16:37:13, size: 612
# Batch sent: 2024-12-19T16:37:13, size: 612
# Batch sent: 2024-12-19T16:37:13, size: 612
# Batch sent: 2024-12-19T16:37:13, size: 613
# Batch sent: 2024-12-19T16:37:13, size: 613
# Batch sent: 2024-12-19T16:37:13, size: 374
